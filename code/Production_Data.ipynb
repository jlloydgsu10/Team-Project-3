# %%
# Dependencies
import pandas as pd
import json
import requests
from config import api_key
from pandas import json_normalize
from pprint import pprint
import matplotlib.pyplot as plt
import numpy as np
from sqlalchemy import create_engine
import psycopg2

# %%
# Save config information
url = "https://api.eia.gov/v2/petroleum/crd/crpdn/data/API_route?api_key="
conditions = "&frequency=monthly&start=2017-05-31&end=2022-07-10&data[]=value&sort[0][column]=period&sort[0][direction]=desc"
conditions2 = "&frequency=monthly&start=2012-06-01&end=2017-05-31&data[]=value&sort[0][column]=period&sort[0][direction]=desc"
conditions3 = "&frequency=monthly&end=2012-06-01&data[]=value&sort[0][column]=period&sort[0][direction]=desc"

# Build query URL
query_url = url + api_key + conditions
query_url2 = url + api_key + conditions2
query_url3 = url + api_key + conditions3

# %%
production_response = requests.get(query_url)
production_json = production_response.json()

df_nested_list = pd.json_normalize(production_json["response"], record_path =['data'])
df_nested_list
# Out:
#        period duoarea area-name product product-name process  \
# 0     2022-04     SOK    USA-OK    EPC0    Crude Oil     FPF
# 1     2022-04     SID    USA-ID    EPC0    Crude Oil     FPF
# 2     2022-04     R5F        NA    EPC0    Crude Oil     FPF
# 3     2022-04     SMO    USA-MO    EPC0    Crude Oil     FPF
# 4     2022-04     SNV    USA-NV    EPC0    Crude Oil     FPF
# ...       ...     ...       ...     ...          ...     ...
# 4951  2017-06     SAL    USA-AL    EPC0    Crude Oil     FPF
# 4952  2017-06     SFL        NA    EPC0    Crude Oil     FPF
# 4953  2017-06     SNM    USA-NM    EPC0    Crude Oil     FPF
# 4954  2017-06     R5F        NA    EPC0    Crude Oil     FPF
# 4955  2017-06     SKS    USA-KS    EPC0    Crude Oil     FPF
#
#           process-name               series  \
# 0     Field Production             MCRFPOK2
# 1     Field Production  M_EPC0_FPF_SID_MBBL
# 2     Field Production             MCRFP5F2
# 3     Field Production             MCRFPMO1
# 4     Field Production             MCRFPNV1
# ...                ...                  ...
# 4951  Field Production             MCRFPAL2
# 4952  Field Production             MCRFPFL2
# 4953  Field Production             MCRFPNM2
# 4954  Field Production             MCRFP5F1
# 4955  Field Production             MCRFPKS1
#
#                                      series-description  value   units
# 0     Oklahoma Field Production of Crude Oil (Thousa...    418  MBBL/D
# 1     Idaho Field Production of Crude Oil (Thousand ...      2    MBBL
# 2     Federal Offshore PADD 5 Field Production of Cr...      7  MBBL/D
# 3     Missouri Field Production of Crude Oil (Thousa...      5    MBBL
# 4     Nevada Field Production of Crude Oil (Thousand...     20    MBBL
# ...                                                 ...    ...     ...
# 4951  Alabama Field Production of Crude Oil (Thousan...     19  MBBL/D
# 4952  Florida Field Production of Crude Oil (Thousan...      5  MBBL/D
# 4953  New Mexico Field Production of Crude Oil (Thou...    443  MBBL/D
# 4954  Federal Offshore PADD 5 Field Production of Cr...    484    MBBL
# 4955  Kansas Field Production of Crude Oil (Thousand...   3043    MBBL
#
# [4956 rows x 11 columns]

# %%
production_response2 = requests.get(query_url2)
production_json2 = production_response2.json()

df_nested_list2 = pd.json_normalize(production_json2["response"], record_path =['data'])
df_nested_list2
# Out:
#        period duoarea   area-name product product-name process  \
# 0     2017-05     STN      USA-TN    EPC0    Crude Oil     FPF
# 1     2017-05     SKS      USA-KS    EPC0    Crude Oil     FPF
# 2     2017-05     SAZ      USA-AZ    EPC0    Crude Oil     FPF
# 3     2017-05     SWV      USA-WV    EPC0    Crude Oil     FPF
# 4     2017-05     SLA      USA-LA    EPC0    Crude Oil     FPF
# ...       ...     ...         ...     ...          ...     ...
# 4951  2012-07    R3FM          NA    EPC0    Crude Oil     FPF
# 4952  2012-07     SMO      USA-MO    EPC0    Crude Oil     FPF
# 4953  2012-07     SCA  CALIFORNIA    EPC0    Crude Oil     FPF
# 4954  2012-07     SNV      USA-NV    EPC0    Crude Oil     FPF
# 4955  2012-07     SMO      USA-MO    EPC0    Crude Oil     FPF
#
#           process-name     series  \
# 0     Field Production   MCRFPTN2
# 1     Field Production   MCRFPKS1
# 2     Field Production   MCRFPAZ1
# 3     Field Production   MCRFPWV2
# 4     Field Production   MCRFPLA1
# ...                ...        ...
# 4951  Field Production  MCRFP3FM1
# 4952  Field Production   MCRFPMO2
# 4953  Field Production   MCRFPCA2
# 4954  Field Production   MCRFPNV1
# 4955  Field Production   MCRFPMO1
#
#                                      series-description  value   units
# 0     Tennessee Field Production of Crude Oil (Thous...      1  MBBL/D
# 1     Kansas Field Production of Crude Oil (Thousand...   3104    MBBL
# 2     Arizona Field Production of Crude Oil (Thousan...      1    MBBL
# 3     West Virginia Field Production of Crude Oil (T...     24  MBBL/D
# 4     Louisiana Field Production of Crude Oil (Thous...   4490    MBBL
# ...                                                 ...    ...     ...
# 4951  Federal Offshore--Gulf of Mexico Field Product...  38801    MBBL
# 4952  Missouri Field Production of Crude Oil (Thousa...      1  MBBL/D
# 4953  California Field Production of Crude Oil (Thou...    541  MBBL/D
# 4954  Nevada Field Production of Crude Oil (Thousand...     30    MBBL
# 4955  Missouri Field Production of Crude Oil (Thousa...     16    MBBL
#
# [4956 rows x 11 columns]

# %%
production_response3 = requests.get(query_url3)
production_json3 = production_response3.json()

df_nested_list3 = pd.json_normalize(production_json3["response"], record_path =['data'])
df_nested_list3
# Out:
#        period duoarea area-name product   product-name process  \
# 0     2012-06     SAK    USA-AK  EPCANS  ANS Crude Oil     FPF
# 1     2012-06     SSD    USA-SD    EPC0      Crude Oil     FPF
# 2     2012-06     SCO  COLORADO    EPC0      Crude Oil     FPF
# 3     2012-06     SVA    USA-VA    EPC0      Crude Oil     FPF
# 4     2012-06     SWV    USA-WV    EPC0      Crude Oil     FPF
# ...       ...     ...       ...     ...            ...     ...
# 4995  2007-07     R40    PADD 4    EPC0      Crude Oil     FPF
# 4996  2007-07     R10    PADD 1    EPC0      Crude Oil     FPF
# 4997  2007-07     SOH      OHIO    EPC0      Crude Oil     FPF
# 4998  2007-07     SAL    USA-AL    EPC0      Crude Oil     FPF
# 4999  2007-07     SNM    USA-NM    EPC0      Crude Oil     FPF
#
#           process-name    series  \
# 0     Field Production  MANFPAK2
# 1     Field Production  MCRFPSD1
# 2     Field Production  MCRFPCO2
# 3     Field Production  MCRFPVA1
# 4     Field Production  MCRFPWV1
# ...                ...       ...
# 4995  Field Production  MCRFPP41
# 4996  Field Production  MCRFPP11
# 4997  Field Production  MCRFPOH1
# 4998  Field Production  MCRFPAL2
# 4999  Field Production  MCRFPNM2
#
#                                      series-description  value   units
# 0     Alaska North Slope Crude Oil Production (Thous...    483  MBBL/D
# 1     South Dakota Field Production of Crude Oil (Th...    146    MBBL
# 2     Colorado Field Production of Crude Oil (Thousa...    127  MBBL/D
# 3     Virginia Field Production of Crude Oil (Thousa...      1    MBBL
# 4     West Virginia Field Production of Crude Oil (T...    205    MBBL
# ...                                                 ...    ...     ...
# 4995  Rocky Mountain (PADD 4) Field Production of Cr...  11400    MBBL
# 4996  East Coast (PADD 1) Field Production of Crude ...    576    MBBL
# 4997  Ohio Field Production of Crude Oil (Thousand B...    438    MBBL
# 4998  Alabama Field Production of Crude Oil (Thousan...     20  MBBL/D
# 4999  New Mexico Field Production of Crude Oil (Thou...    158  MBBL/D
#
# [5000 rows x 11 columns]

# %%
new_df = df_nested_list.append(df_nested_list2)

# %%
combined_df = new_df.append(df_nested_list3)

# Remove all rows with MBBL data
combined_df.drop(combined_df[combined_df.units == 'MBBL'].index, inplace=True)
combined_df.reset_index()
df = combined_df.drop(columns=['duoarea', 'product', 'product-name', 'process', 'process-name', 'series'])
df.reset_index()

df['period'] = pd.to_datetime(df['period'],errors="coerce")

# us_fields = df.groupby(['area-name']).sum()
# Create a list of the area names
# area = [df['area-name'].unique()]
# print(area)
# us_fields.head()
count = df['area-name'].value_counts()
count
# df.to_csv("static/data/us_stateprod.csv", index=True)
# df.head()
# Out:
# NA            193
# USA-AK         96
# PADD 3         56
# USA-PA         54
# USA-NE         53
# USA-UT         52
# USA-MT         52
# USA-NV         52
# NEW YORK       50
# COLORADO       49
# USA-IL         49
# USA-VA         49
# USA-MI         49
# USA-LA         48
# USA-ID         48
# USA-AL         46
# USA-WY         45
# PADD 1         44
# USA-KY         44
# PADD 4         44
# USA-KS         44
# USA-WV         44
# USA-SD         43
# USA-AR         43
# USA-OK         43
# USA-IN         43
# PADD 5         43
# CALIFORNIA     42
# USA-AZ         41
# USA-MS         41
# PADD 2         41
# OHIO           41
# USA-ND         40
# FLORIDA        40
# USA-MO         39
# USA-TN         38
# USA-NM         37
# TEXAS          37
# Name: area-name, dtype: int64

# %%
connection_string = "postgres:postgres@localhost:5432/production_db"
engine = create_engine(f'postgresql://{connection_string}')

# %%
df.to_sql(name='production', con=engine, if_exists='append', index=True)

# %%
engine.table_names()
# Out:
# ['production']

# %%
pd.read_sql_query('select * from production', con=engine).head()
# Out:
#    index     period area-name  value   units
# 0      0 2022-04-01    USA-OK    418  MBBL/D
# 1      7 2022-04-01    USA-WV     47  MBBL/D
# 2     23 2022-04-01    USA-ND    894  MBBL/D
# 3     31 2022-04-01    USA-NM   1507  MBBL/D
# 4     35 2022-04-01    USA-MS     33  MBBL/D
